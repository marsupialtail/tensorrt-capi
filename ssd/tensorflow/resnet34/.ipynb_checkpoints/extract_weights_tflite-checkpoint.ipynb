# %%
import tensorflow as tf
import numpy as np
# Out:
# /home/harsha/anaconda3/envs/tf_p36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/harsha/anaconda3/envs/tf_p36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/harsha/anaconda3/envs/tf_p36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/harsha/anaconda3/envs/tf_p36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/harsha/anaconda3/envs/tf_p36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/harsha/anaconda3/envs/tf_p36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/harsha/anaconda3/envs/tf_p36/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/harsha/anaconda3/envs/tf_p36/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/harsha/anaconda3/envs/tf_p36/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/harsha/anaconda3/envs/tf_p36/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/harsha/anaconda3/envs/tf_p36/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/harsha/anaconda3/envs/tf_p36/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
interpreter = tf.lite.Interpreter(model_path="./ssd_resnet34.tflite")
interpreter.allocate_tensors()

# %%
stuff = interpreter.get_tensor_details()

# %%
stuff
# Out:
# [{'name': 'image',
#   'index': 0,
#   'shape': array([   1, 1200, 1200,    3], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape',
#   'index': 1,
#   'shape': array([    1,    81, 10000], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape/shape',
#   'index': 2,
#   'shape': array([3], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_1',
#   'index': 3,
#   'shape': array([   1,   81, 3750], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_1/shape',
#   'index': 4,
#   'shape': array([3], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_10',
#   'index': 5,
#   'shape': array([ 1,  4, 36], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_10/shape',
#   'index': 6,
#   'shape': array([3], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_11',
#   'index': 7,
#   'shape': array([ 1,  4, 36], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_11/shape',
#   'index': 8,
#   'shape': array([3], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_2',
#   'index': 9,
#   'shape': array([   1,   81, 1014], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_2/shape',
#   'index': 10,
#   'shape': array([3], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_3',
#   'index': 11,
#   'shape': array([  1,  81, 294], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_3/shape',
#   'index': 12,
#   'shape': array([3], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_4',
#   'index': 13,
#   'shape': array([ 1, 81, 36], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_4/shape',
#   'index': 14,
#   'shape': array([3], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_5',
#   'index': 15,
#   'shape': array([ 1, 81, 36], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_5/shape',
#   'index': 16,
#   'shape': array([3], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_6',
#   'index': 17,
#   'shape': array([    1,     4, 10000], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_6/shape',
#   'index': 18,
#   'shape': array([3], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_7',
#   'index': 19,
#   'shape': array([   1,    4, 3750], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_7/shape',
#   'index': 20,
#   'shape': array([3], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_8',
#   'index': 21,
#   'shape': array([   1,    4, 1014], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_8/shape',
#   'index': 22,
#   'shape': array([3], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_9',
#   'index': 23,
#   'shape': array([  1,   4, 294], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/Reshape_9/shape',
#   'index': 24,
#   'shape': array([3], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv10/conv10_1/Conv2D_bias',
#   'index': 25,
#   'shape': array([128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv10/conv10_1/Relu',
#   'index': 26,
#   'shape': array([  1,  19,  19, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv10/conv10_1/kernel/read',
#   'index': 27,
#   'shape': array([128,   1,   1, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv10/conv10_2/Conv2D_bias',
#   'index': 28,
#   'shape': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv10/conv10_2/Relu',
#   'index': 29,
#   'shape': array([  1,   9,   9, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv10/conv10_2/kernel/read',
#   'index': 30,
#   'shape': array([256,   3,   3, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv11/conv11_1/Conv2D_bias',
#   'index': 31,
#   'shape': array([128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv11/conv11_1/Relu',
#   'index': 32,
#   'shape': array([  1,   9,   9, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv11/conv11_1/kernel/read',
#   'index': 33,
#   'shape': array([128,   1,   1, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv11/conv11_2/Conv2D_bias',
#   'index': 34,
#   'shape': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv11/conv11_2/Relu',
#   'index': 35,
#   'shape': array([  1,   7,   7, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv11/conv11_2/kernel/read',
#   'index': 36,
#   'shape': array([256,   3,   3, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv7/conv7_1/Conv2D_bias',
#   'index': 37,
#   'shape': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv7/conv7_1/Relu',
#   'index': 38,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv7/conv7_1/kernel/read',
#   'index': 39,
#   'shape': array([256,   1,   1, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv7/conv7_2/Conv2D_bias',
#   'index': 40,
#   'shape': array([512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv7/conv7_2/Relu',
#   'index': 41,
#   'shape': array([  1,  75,  75, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv7/conv7_2/kernel/read',
#   'index': 42,
#   'shape': array([512,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv8/conv8_1/Conv2D_bias',
#   'index': 43,
#   'shape': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv8/conv8_1/Relu',
#   'index': 44,
#   'shape': array([  1,  75,  75, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv8/conv8_1/kernel/read',
#   'index': 45,
#   'shape': array([256,   1,   1, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv8/conv8_2/Conv2D_bias',
#   'index': 46,
#   'shape': array([512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv8/conv8_2/Relu',
#   'index': 47,
#   'shape': array([  1,  38,  38, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv8/conv8_2/kernel/read',
#   'index': 48,
#   'shape': array([512,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv9/conv9_1/Conv2D_bias',
#   'index': 49,
#   'shape': array([128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv9/conv9_1/Relu',
#   'index': 50,
#   'shape': array([  1,  38,  38, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv9/conv9_1/kernel/read',
#   'index': 51,
#   'shape': array([128,   1,   1, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv9/conv9_2/Conv2D_bias',
#   'index': 52,
#   'shape': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv9/conv9_2/Relu',
#   'index': 53,
#   'shape': array([  1,  19,  19, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/additional_layers/conv9/conv9_2/kernel/read',
#   'index': 54,
#   'shape': array([256,   3,   3, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/conv1/conv1_1/Conv2D_bias',
#   'index': 55,
#   'shape': array([64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/conv1/conv1_1/kernel/read',
#   'index': 56,
#   'shape': array([64,  7,  7,  3], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/conv1/conv1_relu1/conv1_relu1',
#   'index': 57,
#   'shape': array([  1, 600, 600,  64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/cls_0/BiasAdd',
#   'index': 58,
#   'shape': array([  1,  50,  50, 324], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/cls_0/Conv2D_bias',
#   'index': 59,
#   'shape': array([324], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/cls_0/kernel/read',
#   'index': 60,
#   'shape': array([324,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/cls_1/BiasAdd',
#   'index': 61,
#   'shape': array([  1,  25,  25, 486], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/cls_1/Conv2D_bias',
#   'index': 62,
#   'shape': array([486], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/cls_1/kernel/read',
#   'index': 63,
#   'shape': array([486,   3,   3, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/cls_2/BiasAdd',
#   'index': 64,
#   'shape': array([  1,  13,  13, 486], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/cls_2/Conv2D_bias',
#   'index': 65,
#   'shape': array([486], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/cls_2/kernel/read',
#   'index': 66,
#   'shape': array([486,   3,   3, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/cls_3/BiasAdd',
#   'index': 67,
#   'shape': array([  1,   7,   7, 486], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/cls_3/Conv2D_bias',
#   'index': 68,
#   'shape': array([486], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/cls_3/kernel/read',
#   'index': 69,
#   'shape': array([486,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/cls_4/BiasAdd',
#   'index': 70,
#   'shape': array([  1,   3,   3, 324], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/cls_4/Conv2D_bias',
#   'index': 71,
#   'shape': array([324], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/cls_4/kernel/read',
#   'index': 72,
#   'shape': array([324,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/cls_5/BiasAdd',
#   'index': 73,
#   'shape': array([  1,   3,   3, 324], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/cls_5/Conv2D_bias',
#   'index': 74,
#   'shape': array([324], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/cls_5/kernel/read',
#   'index': 75,
#   'shape': array([324,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/loc_0/BiasAdd',
#   'index': 76,
#   'shape': array([ 1, 50, 50, 16], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/loc_0/Conv2D_bias',
#   'index': 77,
#   'shape': array([16], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/loc_0/kernel/read',
#   'index': 78,
#   'shape': array([ 16,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/loc_1/BiasAdd',
#   'index': 79,
#   'shape': array([ 1, 25, 25, 24], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/loc_1/Conv2D_bias',
#   'index': 80,
#   'shape': array([24], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/loc_1/kernel/read',
#   'index': 81,
#   'shape': array([ 24,   3,   3, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/loc_2/BiasAdd',
#   'index': 82,
#   'shape': array([ 1, 13, 13, 24], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/loc_2/Conv2D_bias',
#   'index': 83,
#   'shape': array([24], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/loc_2/kernel/read',
#   'index': 84,
#   'shape': array([ 24,   3,   3, 512], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/loc_3/BiasAdd',
#   'index': 85,
#   'shape': array([ 1,  7,  7, 24], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/loc_3/Conv2D_bias',
#   'index': 86,
#   'shape': array([24], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/loc_3/kernel/read',
#   'index': 87,
#   'shape': array([ 24,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/loc_4/BiasAdd',
#   'index': 88,
#   'shape': array([ 1,  3,  3, 16], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/loc_4/Conv2D_bias',
#   'index': 89,
#   'shape': array([16], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/loc_4/kernel/read',
#   'index': 90,
#   'shape': array([ 16,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/loc_5/BiasAdd',
#   'index': 91,
#   'shape': array([ 1,  3,  3, 16], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/loc_5/Conv2D_bias',
#   'index': 92,
#   'shape': array([16], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/multibox_head/loc_5/kernel/read',
#   'index': 93,
#   'shape': array([ 16,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/pool1/MaxPool',
#   'index': 94,
#   'shape': array([  1, 300, 300,  64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/py_cls_pred',
#   'index': 95,
#   'shape': array([    1,    81, 15130], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/py_location_pred',
#   'index': 96,
#   'shape': array([    1,     4, 15130], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block1/stage1_residul_block1_1/Conv2D_bias',
#   'index': 97,
#   'shape': array([64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block1/stage1_residul_block1_1/kernel/read',
#   'index': 98,
#   'shape': array([64,  3,  3, 64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block1/stage1_residul_block1_2/Conv2D_bias',
#   'index': 99,
#   'shape': array([64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block1/stage1_residul_block1_2/kernel/read',
#   'index': 100,
#   'shape': array([64,  3,  3, 64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block1/stage1_residul_block1_bn2/FusedBatchNorm',
#   'index': 101,
#   'shape': array([  1, 300, 300,  64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block1/stage1_residul_block1_relu1/stage1_residul_block1_relu1',
#   'index': 102,
#   'shape': array([  1, 300, 300,  64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block1/stage1_residul_block1_relu2/stage1_residul_block1_relu2',
#   'index': 103,
#   'shape': array([  1, 300, 300,  64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block2/stage1_residul_block2_1/Conv2D_bias',
#   'index': 104,
#   'shape': array([64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block2/stage1_residul_block2_1/kernel/read',
#   'index': 105,
#   'shape': array([64,  3,  3, 64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block2/stage1_residul_block2_2/Conv2D_bias',
#   'index': 106,
#   'shape': array([64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block2/stage1_residul_block2_2/kernel/read',
#   'index': 107,
#   'shape': array([64,  3,  3, 64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block2/stage1_residul_block2_bn2/FusedBatchNorm',
#   'index': 108,
#   'shape': array([  1, 300, 300,  64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block2/stage1_residul_block2_relu1/stage1_residul_block2_relu1',
#   'index': 109,
#   'shape': array([  1, 300, 300,  64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block2/stage1_residul_block2_relu2/stage1_residul_block2_relu2',
#   'index': 110,
#   'shape': array([  1, 300, 300,  64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block3/stage1_residul_block3_1/Conv2D_bias',
#   'index': 111,
#   'shape': array([64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block3/stage1_residul_block3_1/kernel/read',
#   'index': 112,
#   'shape': array([64,  3,  3, 64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block3/stage1_residul_block3_2/Conv2D_bias',
#   'index': 113,
#   'shape': array([64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block3/stage1_residul_block3_2/kernel/read',
#   'index': 114,
#   'shape': array([64,  3,  3, 64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block3/stage1_residul_block3_bn2/FusedBatchNorm',
#   'index': 115,
#   'shape': array([  1, 300, 300,  64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block3/stage1_residul_block3_relu1/stage1_residul_block3_relu1',
#   'index': 116,
#   'shape': array([  1, 300, 300,  64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage1_residul_block3/stage1_residul_block3_relu2/stage1_residul_block3_relu2',
#   'index': 117,
#   'shape': array([  1, 300, 300,  64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_downsample/stage2_downsample_1/Conv2D_bias',
#   'index': 118,
#   'shape': array([128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_downsample/stage2_downsample_1/kernel/read',
#   'index': 119,
#   'shape': array([128,   1,   1,  64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_downsample/stage2_downsample_bn1/FusedBatchNorm',
#   'index': 120,
#   'shape': array([  1, 150, 150, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block1_1/stage2_residul_block1_1_1/Conv2D_bias',
#   'index': 121,
#   'shape': array([128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block1_1/stage2_residul_block1_1_1/kernel/read',
#   'index': 122,
#   'shape': array([128,   3,   3,  64], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block1_1/stage2_residul_block1_1_relu1/stage2_residul_block1_1_relu1',
#   'index': 123,
#   'shape': array([  1, 150, 150, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block1_2/stage2_residul_block1_2_1/Conv2D_bias',
#   'index': 124,
#   'shape': array([128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block1_2/stage2_residul_block1_2_1/kernel/read',
#   'index': 125,
#   'shape': array([128,   3,   3, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block1_2/stage2_residul_block1_2_bn1/FusedBatchNorm',
#   'index': 126,
#   'shape': array([  1, 150, 150, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block1_2/stage2_residul_block1_2_relu1/stage2_residul_block1_2_relu1',
#   'index': 127,
#   'shape': array([  1, 150, 150, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block2/stage2_residul_block2_1/Conv2D_bias',
#   'index': 128,
#   'shape': array([128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block2/stage2_residul_block2_1/kernel/read',
#   'index': 129,
#   'shape': array([128,   3,   3, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block2/stage2_residul_block2_2/Conv2D_bias',
#   'index': 130,
#   'shape': array([128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block2/stage2_residul_block2_2/kernel/read',
#   'index': 131,
#   'shape': array([128,   3,   3, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block2/stage2_residul_block2_bn2/FusedBatchNorm',
#   'index': 132,
#   'shape': array([  1, 150, 150, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block2/stage2_residul_block2_relu1/stage2_residul_block2_relu1',
#   'index': 133,
#   'shape': array([  1, 150, 150, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block2/stage2_residul_block2_relu2/stage2_residul_block2_relu2',
#   'index': 134,
#   'shape': array([  1, 150, 150, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block3/stage2_residul_block3_1/Conv2D_bias',
#   'index': 135,
#   'shape': array([128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block3/stage2_residul_block3_1/kernel/read',
#   'index': 136,
#   'shape': array([128,   3,   3, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block3/stage2_residul_block3_2/Conv2D_bias',
#   'index': 137,
#   'shape': array([128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block3/stage2_residul_block3_2/kernel/read',
#   'index': 138,
#   'shape': array([128,   3,   3, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block3/stage2_residul_block3_bn2/FusedBatchNorm',
#   'index': 139,
#   'shape': array([  1, 150, 150, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block3/stage2_residul_block3_relu1/stage2_residul_block3_relu1',
#   'index': 140,
#   'shape': array([  1, 150, 150, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block3/stage2_residul_block3_relu2/stage2_residul_block3_relu2',
#   'index': 141,
#   'shape': array([  1, 150, 150, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block4/stage2_residul_block4_1/Conv2D_bias',
#   'index': 142,
#   'shape': array([128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block4/stage2_residul_block4_1/kernel/read',
#   'index': 143,
#   'shape': array([128,   3,   3, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block4/stage2_residul_block4_2/Conv2D_bias',
#   'index': 144,
#   'shape': array([128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block4/stage2_residul_block4_2/kernel/read',
#   'index': 145,
#   'shape': array([128,   3,   3, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block4/stage2_residul_block4_bn2/FusedBatchNorm',
#   'index': 146,
#   'shape': array([  1, 150, 150, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block4/stage2_residul_block4_relu1/stage2_residul_block4_relu1',
#   'index': 147,
#   'shape': array([  1, 150, 150, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage2_residul_block4/stage2_residul_block4_relu2/stage2_residul_block4_relu2',
#   'index': 148,
#   'shape': array([  1, 150, 150, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_downsample/stage3_downsample_1/Conv2D_bias',
#   'index': 149,
#   'shape': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_downsample/stage3_downsample_1/kernel/read',
#   'index': 150,
#   'shape': array([256,   1,   1, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_downsample/stage3_downsample_bn1/FusedBatchNorm',
#   'index': 151,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block1/stage3_residul_block1_1/Conv2D_bias',
#   'index': 152,
#   'shape': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block1/stage3_residul_block1_1/kernel/read',
#   'index': 153,
#   'shape': array([256,   3,   3, 128], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block1/stage3_residul_block1_2/Conv2D_bias',
#   'index': 154,
#   'shape': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block1/stage3_residul_block1_2/kernel/read',
#   'index': 155,
#   'shape': array([256,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block1/stage3_residul_block1_bn2/FusedBatchNorm',
#   'index': 156,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block1/stage3_residul_block1_relu1/stage3_residul_block1_relu1',
#   'index': 157,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block1/stage3_residul_block1_relu2/stage3_residul_block1_relu2',
#   'index': 158,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block2/stage3_residul_block2_1/Conv2D_bias',
#   'index': 159,
#   'shape': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block2/stage3_residul_block2_1/kernel/read',
#   'index': 160,
#   'shape': array([256,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block2/stage3_residul_block2_2/Conv2D_bias',
#   'index': 161,
#   'shape': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block2/stage3_residul_block2_2/kernel/read',
#   'index': 162,
#   'shape': array([256,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block2/stage3_residul_block2_bn2/FusedBatchNorm',
#   'index': 163,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block2/stage3_residul_block2_relu1/stage3_residul_block2_relu1',
#   'index': 164,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block2/stage3_residul_block2_relu2/stage3_residul_block2_relu2',
#   'index': 165,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block3/stage3_residul_block3_1/Conv2D_bias',
#   'index': 166,
#   'shape': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block3/stage3_residul_block3_1/kernel/read',
#   'index': 167,
#   'shape': array([256,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block3/stage3_residul_block3_2/Conv2D_bias',
#   'index': 168,
#   'shape': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block3/stage3_residul_block3_2/kernel/read',
#   'index': 169,
#   'shape': array([256,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block3/stage3_residul_block3_bn2/FusedBatchNorm',
#   'index': 170,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block3/stage3_residul_block3_relu1/stage3_residul_block3_relu1',
#   'index': 171,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block3/stage3_residul_block3_relu2/stage3_residul_block3_relu2',
#   'index': 172,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block4/stage3_residul_block4_1/Conv2D_bias',
#   'index': 173,
#   'shape': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block4/stage3_residul_block4_1/kernel/read',
#   'index': 174,
#   'shape': array([256,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block4/stage3_residul_block4_2/Conv2D_bias',
#   'index': 175,
#   'shape': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block4/stage3_residul_block4_2/kernel/read',
#   'index': 176,
#   'shape': array([256,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block4/stage3_residul_block4_bn2/FusedBatchNorm',
#   'index': 177,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block4/stage3_residul_block4_relu1/stage3_residul_block4_relu1',
#   'index': 178,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block4/stage3_residul_block4_relu2/stage3_residul_block4_relu2',
#   'index': 179,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block5/stage3_residul_block5_1/Conv2D_bias',
#   'index': 180,
#   'shape': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block5/stage3_residul_block5_1/kernel/read',
#   'index': 181,
#   'shape': array([256,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block5/stage3_residul_block5_2/Conv2D_bias',
#   'index': 182,
#   'shape': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block5/stage3_residul_block5_2/kernel/read',
#   'index': 183,
#   'shape': array([256,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block5/stage3_residul_block5_bn2/FusedBatchNorm',
#   'index': 184,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block5/stage3_residul_block5_relu1/stage3_residul_block5_relu1',
#   'index': 185,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block5/stage3_residul_block5_relu2/stage3_residul_block5_relu2',
#   'index': 186,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block6/stage3_residul_block6_1/Conv2D_bias',
#   'index': 187,
#   'shape': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block6/stage3_residul_block6_1/kernel/read',
#   'index': 188,
#   'shape': array([256,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block6/stage3_residul_block6_2/Conv2D_bias',
#   'index': 189,
#   'shape': array([256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block6/stage3_residul_block6_2/kernel/read',
#   'index': 190,
#   'shape': array([256,   3,   3, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block6/stage3_residul_block6_bn2/FusedBatchNorm',
#   'index': 191,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block6/stage3_residul_block6_relu1/stage3_residul_block6_relu1',
#   'index': 192,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/stage3_residul_block6/stage3_residul_block6_relu2/stage3_residul_block6_relu2',
#   'index': 193,
#   'shape': array([  1, 150, 150, 256], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose',
#   'index': 194,
#   'shape': array([  1, 324,  50,  50], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose/perm',
#   'index': 195,
#   'shape': array([4], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_1',
#   'index': 196,
#   'shape': array([  1, 486,  25,  25], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_1/perm',
#   'index': 197,
#   'shape': array([4], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_10',
#   'index': 198,
#   'shape': array([ 1, 16,  3,  3], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_10/perm',
#   'index': 199,
#   'shape': array([4], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_11',
#   'index': 200,
#   'shape': array([ 1, 16,  3,  3], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_11/perm',
#   'index': 201,
#   'shape': array([4], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_2',
#   'index': 202,
#   'shape': array([  1, 486,  13,  13], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_2/perm',
#   'index': 203,
#   'shape': array([4], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_3',
#   'index': 204,
#   'shape': array([  1, 486,   7,   7], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_3/perm',
#   'index': 205,
#   'shape': array([4], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_4',
#   'index': 206,
#   'shape': array([  1, 324,   3,   3], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_4/perm',
#   'index': 207,
#   'shape': array([4], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_5',
#   'index': 208,
#   'shape': array([  1, 324,   3,   3], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_5/perm',
#   'index': 209,
#   'shape': array([4], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_6',
#   'index': 210,
#   'shape': array([ 1, 16, 50, 50], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_6/perm',
#   'index': 211,
#   'shape': array([4], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_7',
#   'index': 212,
#   'shape': array([ 1, 24, 25, 25], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_7/perm',
#   'index': 213,
#   'shape': array([4], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_8',
#   'index': 214,
#   'shape': array([ 1, 24, 13, 13], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_8/perm',
#   'index': 215,
#   'shape': array([4], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_9',
#   'index': 216,
#   'shape': array([ 1, 24,  7,  7], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0)},
#  {'name': 'ssd1200/transpose_9/perm',
#   'index': 217,
#   'shape': array([4], dtype=int32),
#   'dtype': numpy.int32,
#   'quantization': (0.0, 0)}]

# %%
bias_tensors_meta = []
bias_tensors = []

for j in range(len(stuff)):
    if "bias" in stuff[j]['name']:
        bias_tensors_meta.append(stuff[j])
        bias_tensors.append(interpreter.get_tensor(j))
        name = bias_tensors_meta[-1]['name'].split("/")[1]
        print(name, bias_tensors[-1].shape)
        
        np.save(name + "_bias.npy",bias_tensors[-1])
# Out:
# additional_layers (128,)
# additional_layers (256,)
# additional_layers (128,)
# additional_layers (256,)
# additional_layers (256,)
# additional_layers (512,)
# additional_layers (256,)
# additional_layers (512,)
# additional_layers (128,)
# additional_layers (256,)
# conv1 (64,)
# multibox_head (324,)
# multibox_head (486,)
# multibox_head (486,)
# multibox_head (486,)
# multibox_head (324,)
# multibox_head (324,)
# multibox_head (16,)
# multibox_head (24,)
# multibox_head (24,)
# multibox_head (24,)
# multibox_head (16,)
# multibox_head (16,)
# stage1_residul_block1 (64,)
# stage1_residul_block1 (64,)
# stage1_residul_block2 (64,)
# stage1_residul_block2 (64,)
# stage1_residul_block3 (64,)
# stage1_residul_block3 (64,)
# stage2_downsample (128,)
# stage2_residul_block1_1 (128,)
# stage2_residul_block1_2 (128,)
# stage2_residul_block2 (128,)
# stage2_residul_block2 (128,)
# stage2_residul_block3 (128,)
# stage2_residul_block3 (128,)
# stage2_residul_block4 (128,)
# stage2_residul_block4 (128,)
# stage3_downsample (256,)
# stage3_residul_block1 (256,)
# stage3_residul_block1 (256,)
# stage3_residul_block2 (256,)
# stage3_residul_block2 (256,)
# stage3_residul_block3 (256,)
# stage3_residul_block3 (256,)
# stage3_residul_block4 (256,)
# stage3_residul_block4 (256,)
# stage3_residul_block5 (256,)
# stage3_residul_block5 (256,)
# stage3_residul_block6 (256,)
# stage3_residul_block6 (256,)

# %%
for j in range(len(stuff)):
    if "kernel" in stuff[j]['name']:
        weight_tensors_meta.append(stuff[j])
        weight_tensors.append(interpreter.get_tensor(j))
        name = weight_tensors_meta[-1]['name'].split("/")[1]
        print(name, weight_tensors[-1].shape)
        np.save(name + ".npy",weight_tensors[-1].squeeze())
        #if "depthwise" not in name:
        #    np.save(name + ".npy",weight_tensors[-1].squeeze().transpose())
        #else:
        #    np.save(name + ".npy",weight_tensors[-1])
# Out:
# final_dense (1000, 1024)
# initial_conv (32, 3, 3, 3)

# %%
weight_tensors_meta = []
weight_tensors = []

for j in range(len(stuff)):
    if "weight" in stuff[j]['name']:
        weight_tensors_meta.append(stuff[j])
        weight_tensors.append(interpreter.get_tensor(j))
        name = weight_tensors_meta[-1]['name'].split("/")[1]
        print(name, weight_tensors[-1].shape)
        np.save(name + ".npy",weight_tensors[-1].squeeze())
        #if "depthwise" not in name:
        #    np.save(name + ".npy",weight_tensors[-1].squeeze().transpose())
        #else:
        #    np.save(name + ".npy",weight_tensors[-1])
# Out:
# contraction_1x1_0 (64, 1, 1, 32)
# contraction_1x1_1 (128, 1, 1, 64)
# contraction_1x1_10 (512, 1, 1, 512)
# contraction_1x1_11 (1024, 1, 1, 512)
# contraction_1x1_12 (1024, 1, 1, 1024)
# contraction_1x1_2 (128, 1, 1, 128)
# contraction_1x1_3 (256, 1, 1, 128)
# contraction_1x1_4 (256, 1, 1, 256)
# contraction_1x1_5 (512, 1, 1, 256)
# contraction_1x1_6 (512, 1, 1, 512)
# contraction_1x1_7 (512, 1, 1, 512)
# contraction_1x1_8 (512, 1, 1, 512)
# contraction_1x1_9 (512, 1, 1, 512)
# depthwise_nxn_0 (1, 3, 3, 32)
# depthwise_nxn_1 (1, 3, 3, 64)
# depthwise_nxn_10 (1, 3, 3, 512)
# depthwise_nxn_11 (1, 3, 3, 512)
# depthwise_nxn_12 (1, 3, 3, 1024)
# depthwise_nxn_2 (1, 3, 3, 128)
# depthwise_nxn_3 (1, 3, 3, 128)
# depthwise_nxn_4 (1, 3, 3, 256)
# depthwise_nxn_5 (1, 3, 3, 256)
# depthwise_nxn_6 (1, 3, 3, 512)
# depthwise_nxn_7 (1, 3, 3, 512)
# depthwise_nxn_8 (1, 3, 3, 512)
# depthwise_nxn_9 (1, 3, 3, 512)

# %%
test = torch.Tensor(weight_tensors[0].squeeze().transpose())

# %%
groupwise_filters.shape
# Out:
# torch.Size([64, 32, 1, 1])

# %%
weight_tensors[13].shape
# Out:
# (1, 3, 3, 32)

# %%
depthwise_filters = torch.Tensor(weight_tensors[13]).permute(3,0,1,2)
groupwise_filters = torch.Tensor(weight_tensors[0]).permute(0,3,1,2)
depthwise_bias = torch.Tensor(bias_tensors[13])
groupwise_bias = torch.Tensor(bias_tensors[0])

# %%
bias_tensors[13][10]
# Out:
# 1.0047193

# %%
import torch
import torch.nn as nn

# %%
input_image = torch.Tensor(np.random.normal(size=(1,32,112,112)))

intermediate = torch.nn.functional.conv2d(input_image, depthwise_filters, bias=depthwise_bias, stride=1, padding=1, dilation=1, groups=32)
intermediate = torch.nn.functional.relu(intermediate)
result_2 = torch.nn.functional.linear(torch.squeeze(intermediate).permute(1,2,0).contiguous().view(-1,32).unsqueeze(0),torch.squeeze(groupwise_filters),bias=None)
result_1 = torch.nn.functional.conv2d(intermediate,groupwise_filters,bias=groupwise_bias,stride=1,padding=0,dilation=1,groups=1)
result_2 = torch.nn.functional.relu(result_2)
result_1 = torch.nn.functional.relu(result_1)

# %%
torch.sum(result_1) - torch.sum(result_2)
# Out:
# tensor(0.0098)

# %%
np.save("input_image.npy",input_image.squeeze().data.numpy())
np.save("depthwise_filters.npy",depthwise_filters.squeeze().data.numpy())
np.save("result.npy",np.transpose(result_2.squeeze().data.numpy()))

# %%
test = result_2.squeeze().data.numpy()

# %%
test = np.transpose(test)

# %%
test[61,12543]
# Out:
# -1.3124201

# %%
intermediate.squeeze()[0]
# Out:
# tensor([[ 0.3831,  3.1401, -0.2365,  ..., -0.8050, -0.1198,  0.1245],
#         [ 0.1245,  1.8276, -2.1608,  ..., -0.0477, -0.0148, -0.2394],
#         [-0.0652,  0.7686, -0.8525,  ..., -0.5748, -0.0579,  0.3943],
#         ...,
#         [-0.7536,  0.3495,  0.3431,  ...,  0.4957, -1.0231, -0.2651],
#         [-0.7002, -0.6451,  0.9609,  ...,  0.6272,  0.3472, -0.5790],
#         [-0.0169, -0.6897,  0.1856,  ...,  0.5823,  0.4537, -0.2379]])

# %%
input_image.shape
# Out:
# torch.Size([1, 32, 112, 112])

# %%
result_1
# Out:
# tensor([[[[ 27.6783,  13.3509,   2.4749,  ...,   2.0456,  14.0760,  16.8017],
#           [-17.8845, -20.6757,  -0.1477,  ..., -10.1470,   3.7224,  -7.5688],
#           [  9.3705,   3.1455, -13.5922,  ...,  18.8626,  13.5485,  10.4557],
#           ...,
#           [  1.3922,  -6.2970,  -3.5007,  ...,  -5.7171,   6.1289,  16.2437],
#           [  0.8641,   2.9974,  -2.1938,  ...,   6.6196, -19.6970, -23.5239],
#           [ -5.5657,  -6.7367,  -2.7290,  ...,  -3.3473,  18.6799,  14.2540]],
#
#          [[-26.0592,  24.4582,  24.6935,  ..., -10.0700, -16.1549,   1.1208],
#           [ -2.2788,  13.5296, -18.5339,  ...,   3.3453, -13.1331, -11.1933],
#           [ 14.2997, -12.3467, -21.8211,  ...,  23.3961, -20.3506,   3.8412],
#           ...,
#           [ -3.3056, -17.2721,  36.0502,  ...,  12.2551,  26.8922,  -5.6885],
#           [  1.6112,   6.4582, -11.0355,  ..., -19.4557,  -6.5783, -44.5635],
#           [  2.2428,  17.1340,  -3.4808,  ...,   5.8531,   9.1191, -10.5080]],
#
#          [[ -1.8048,   4.3149,   0.3001,  ...,  -2.0521,   2.8436,  -3.9529],
#           [ -1.3115,  -1.5751,  -2.4183,  ...,  -0.8014,  -0.2287,  -5.9840],
#           [  2.7071,  -1.3315,   7.0303,  ...,  -0.4597,  -7.3331,  -2.0337],
#           ...,
#           [  2.3393,   0.5954,  -2.6022,  ...,  -0.2433,   0.7719,   2.5578],
#           [ -5.0148,   4.0513,   2.9885,  ...,  -7.8524,  -0.4524,   5.5811],
#           [  1.6535,   0.7835,   1.5813,  ...,  -2.1391,   4.8363,  -7.6332]],
#
#          ...,
#
#          [[  0.7121,  -6.9704,   3.8111,  ...,   5.4334,   1.1944,   5.7682],
#           [ -4.6059,   1.4771,  -1.2114,  ...,   1.2090,  -5.8075,   4.3345],
#           [  1.1413,  -4.0859,  -0.4871,  ...,  -6.9349,  11.8252,  -2.1323],
#           ...,
#           [ -1.4611,  -2.5021,   2.6067,  ...,   2.6411,   0.6290,  -1.8686],
#           [  8.5371, -10.5192,   4.3571,  ...,   2.6191,  -2.0575,   3.3760],
#           [ -4.8348,   4.5999,  -0.3651,  ...,   7.5995,  -0.1831,  -1.3124]],
#
#          [[ -6.0586,  -2.6133,   3.4186,  ...,   2.8079,  -6.7461,  -7.0936],
#           [ -1.3689,   1.4235,  -5.7621,  ...,  -8.1543,   2.9344,   6.5319],
#           [-12.5553,   7.6774,   9.4049,  ...,  15.3604,   1.2344,  -6.0152],
#           ...,
#           [ -9.2046,  -4.8074,   7.0019,  ...,   6.6249,  -0.8627,  -4.0365],
#           [  2.9153,   7.1841,  -6.0329,  ...,   8.8737,   7.3694, -15.0283],
#           [  4.8919,  -5.5336,   0.2384,  ..., -11.5105,   0.2560,   7.6817]],
#
#          [[ 10.8406,   8.4961,  -7.3745,  ...,   0.3164,  10.8335,   2.2435],
#           [  3.0343,  -6.2978,   6.9613,  ...,  10.0678,  -3.9931,  -4.6485],
#           [ 12.9627,  -5.3803, -11.2961,  ..., -22.2860,  -5.9521,   9.2405],
#           ...,
#           [ 13.8203,  11.2399, -14.2299,  ..., -15.5621,   2.8334,   1.9468],
#           [ -5.0200,  -7.5836,   5.4835,  ...,  -8.6329, -11.7161,  11.4766],
#           [ -6.6028,   7.4370,   1.8634,  ...,  14.9172,  -0.3706,  -5.7627]]]])

# %%
padded_in = torch.nn.functional.pad(input_image,(8,8,1,1))
np.save("padded_input_image.npy",padded_in.squeeze().data.numpy())
padded_out = torch.nn.functional.pad(result_1,(8,8,1,1))
np.save("padded_result.npy",padded_out.squeeze().data.numpy())

# %%
padded_in.shape
# Out:
# torch.Size([1, 32, 114, 128])

# %%
result_1
# Out:
# tensor([[[[-8.2532e+00,  2.4404e-01,  2.1567e+00,  ..., -6.3138e+00,
#             1.5515e+00, -1.4319e+00],
#           [ 1.0238e+01, -1.9175e+00, -2.1251e+00,  ...,  1.3523e+01,
#             1.2930e+01,  3.6847e+00],
#           [-1.8377e+00,  1.4036e+01, -3.4309e+00,  ...,  4.6984e+00,
#             5.1230e+00, -9.2765e+00],
#           ...,
#           [-7.1223e+00,  7.5712e+00,  1.1183e+01,  ..., -3.1568e+00,
#             3.9006e+00,  9.1621e+00],
#           [ 9.9815e+00,  1.0439e+00, -1.0966e+01,  ...,  8.8902e+00,
#            -7.5760e+00, -3.7577e+00],
#           [-5.4394e+00, -4.6471e+00,  2.2216e+00,  ..., -5.8488e+00,
#            -5.7052e-01,  1.4504e+00]],
#
#          [[ 9.6889e+00, -1.1620e+01, -6.4342e-01,  ..., -1.4074e+01,
#             5.8309e+00, -2.4467e+00],
#           [ 1.6686e+01,  2.3070e+01,  2.7790e+01,  ..., -1.5299e+01,
#             4.1484e-01, -1.0877e+01],
#           [-7.3470e+00, -2.3827e+01,  1.6164e+01,  ...,  1.1178e+01,
#             3.7137e+00,  7.5952e+00],
#           ...,
#           [-4.5856e+00,  9.5066e+00, -1.4384e+01,  ..., -2.7885e+01,
#             3.2961e+01, -2.0375e+01],
#           [ 2.7336e+01,  2.6577e+00,  6.2745e+00,  ...,  7.5861e+01,
#            -1.1925e+01,  2.5434e+01],
#           [-4.4691e+00,  2.4801e+01,  9.0334e+00,  ..., -7.1896e+00,
#            -1.5051e+01,  8.5771e+00]],
#
#          [[-1.9528e+00,  1.9544e+00, -1.1265e-01,  ..., -2.6940e+00,
#             7.9780e-01,  1.6097e+00],
#           [ 2.0344e+00, -1.2896e+00,  2.7810e+00,  ...,  2.3411e+00,
#            -8.3969e-01,  3.0641e+00],
#           [ 5.0008e-01, -3.5336e+00,  1.3906e+00,  ..., -3.0010e+00,
#             9.4229e-01, -3.2287e+00],
#           ...,
#           [-4.7810e-01, -1.0593e+01,  6.0644e+00,  ...,  1.3901e+00,
#             6.3465e-01, -1.5612e+00],
#           [ 2.6422e+00,  2.2025e+00, -2.9055e+00,  ..., -7.8674e+00,
#            -8.3976e-01, -2.2714e+00],
#           [ 2.5372e+00, -4.5996e+00,  5.7593e+00,  ..., -2.3288e+00,
#             2.5124e+00,  2.0755e+00]],
#
#          ...,
#
#          [[ 3.9496e+00,  1.2730e-01, -4.4802e+00,  ...,  5.0038e+00,
#             9.2399e-02, -4.2201e+00],
#           [ 1.9178e+00, -3.9855e+00,  7.5327e-01,  ..., -5.0984e+00,
#            -4.3864e-01, -4.5307e+00],
#           [-8.6805e+00,  6.9064e+00, -3.6444e+00,  ...,  2.4568e+00,
#             2.5288e+00,  5.0692e+00],
#           ...,
#           [ 3.1048e+00,  6.7372e+00, -6.5402e+00,  ..., -4.0125e+00,
#             1.0459e+00,  3.8374e+00],
#           [-2.4736e+00,  6.1577e+00,  5.8357e-01,  ..., -2.1989e-02,
#             5.0870e+00, -2.3536e+00],
#           [-1.9634e+00,  4.5859e+00, -9.7534e-01,  ...,  3.7156e+00,
#             2.2193e+00, -1.1772e+00]],
#
#          [[-1.2515e+01,  1.0756e+01,  1.1436e+01,  ..., -2.6772e+00,
#             1.8419e+00, -5.0595e+00],
#           [-2.3091e+00, -1.2027e+00, -1.1242e+01,  ...,  1.8878e+00,
#            -2.1201e+00, -3.2827e+00],
#           [ 8.3019e+00,  8.5319e+00, -3.8972e+00,  ..., -1.9588e+01,
#            -1.2164e+00,  9.3700e+00],
#           ...,
#           [-7.2821e+00, -1.7378e+01,  7.9671e+00,  ...,  8.8131e-01,
#             1.3493e+01, -1.1574e+01],
#           [ 3.4276e+00,  1.8644e+01, -6.0562e+00,  ...,  3.9637e+00,
#            -3.3075e+00,  9.1488e+00],
#           [ 2.4474e+00, -7.8695e+00,  8.5082e+00,  ...,  1.6967e+00,
#            -3.6201e+00, -3.1488e+00]],
#
#          [[ 1.6884e+01, -2.0900e+01, -1.8449e+01,  ..., -1.8179e+00,
#            -1.0936e+01,  9.5337e+00],
#           [ 1.1324e+01,  4.1718e+00,  1.3118e+01,  ...,  1.1516e+01,
#             1.0600e+01,  2.8609e+00],
#           [-1.6257e+01, -1.7054e+01,  1.0626e+01,  ...,  2.4609e+01,
#            -8.5917e+00, -1.8807e+01],
#           ...,
#           [ 4.6612e+00,  3.0288e+01, -1.5772e+01,  ..., -2.1542e+00,
#            -1.7999e+01,  1.9475e+01],
#           [ 3.7187e+00, -3.3349e+01,  1.0686e+01,  ..., -4.9542e+00,
#             7.9448e+00, -1.0002e+01],
#           [-5.6012e+00,  1.2766e+01, -1.3154e+01,  ..., -2.2818e+00,
#             2.2214e+00,  2.1560e+00]]]])
